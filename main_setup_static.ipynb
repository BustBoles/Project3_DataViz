# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pathlib as path

# %%
#Import CSV
aggregate = pd.read_csv('Resources/PROV_US_AGGREGATE20.CSV')
med_data = pd.DataFrame(aggregate)
med_data.head()
# Out:
#    Code                                        Item          Group  \
# 0     1  Personal Health Care (Millions of Dollars)  United States
# 1     1  Personal Health Care (Millions of Dollars)         Region
# 2     1  Personal Health Care (Millions of Dollars)          State
# 3     1  Personal Health Care (Millions of Dollars)          State
# 4     1  Personal Health Care (Millions of Dollars)          State
#
#    Region_Number    REGION_NAME     State_Name   Y1980   Y1981   Y1982  \
# 0              0  United States            NaN  214321  248626  279493
# 1              1    New England            NaN   12830   14696   16591
# 2              1    New England    Connecticut    3135    3612    4134
# 3              1    New England          Maine     975    1113    1259
# 4              1    New England  Massachusetts    6681    7622    8528
#
#     Y1983  ...    Y2012    Y2013    Y2014    Y2015    Y2016    Y2017    Y2018  \
# 0  308006  ...  2346962  2405667  2527325  2674089  2795322  2905160  3021796
# 1   18253  ...   138949   142116   147335   155204   161570   166222   172908
# 2    4587  ...    33053    33864    35243    36774    38059    38987    40587
# 3    1388  ...    11254    11325    11759    12356    12940    13489    14273
# 4    9306  ...    68298    69806    72256    76803    80436    82772    86111
#
#      Y2019    Y2020  Average_Annual_Percent_Growth
# 0  3175230  3357832                            7.1
# 1   180314   189004                            7.0
# 2    42192    44372                            6.8
# 3    15037    15912                            7.2
# 4    89902    93737                            6.8
#
# [5 rows x 48 columns]

# %%
med_data.rename(columns = {'Region_Number': 'Region(#)', 'REGION_NAME': 'Region', 'State_Name': 'State'}, inplace = True)
med_data.head()
# Out:
#    Code                                        Item          Group  Region(#)  \
# 0     1  Personal Health Care (Millions of Dollars)  United States          0
# 1     1  Personal Health Care (Millions of Dollars)         Region          1
# 2     1  Personal Health Care (Millions of Dollars)          State          1
# 3     1  Personal Health Care (Millions of Dollars)          State          1
# 4     1  Personal Health Care (Millions of Dollars)          State          1
#
#           Region          State   Y1980   Y1981   Y1982   Y1983  ...    Y2012  \
# 0  United States            NaN  214321  248626  279493  308006  ...  2346962
# 1    New England            NaN   12830   14696   16591   18253  ...   138949
# 2    New England    Connecticut    3135    3612    4134    4587  ...    33053
# 3    New England          Maine     975    1113    1259    1388  ...    11254
# 4    New England  Massachusetts    6681    7622    8528    9306  ...    68298
#
#      Y2013    Y2014    Y2015    Y2016    Y2017    Y2018    Y2019    Y2020  \
# 0  2405667  2527325  2674089  2795322  2905160  3021796  3175230  3357832
# 1   142116   147335   155204   161570   166222   172908   180314   189004
# 2    33864    35243    36774    38059    38987    40587    42192    44372
# 3    11325    11759    12356    12940    13489    14273    15037    15912
# 4    69806    72256    76803    80436    82772    86111    89902    93737
#
#    Average_Annual_Percent_Growth
# 0                            7.1
# 1                            7.0
# 2                            6.8
# 3                            7.2
# 4                            6.8
#
# [5 rows x 48 columns]

# %%
med_data.rename(columns = {'Y1980': '1980', 'Y1981': '1981', 'Y1982': '1982', 'Y1983': '1983',\
                          'Y1984': '1984', 'Y1985': '1985', 'Y1986': '1986', \
                          'Y1988': '1988', 'Y1989': '1989', 'Y1990': '1990', \
                          'Y1991': '1991', 'Y1992': '1992', 'Y1993': '1993', \
                          'Y1994': '1994', 'Y1995': '1995', 'Y1996': '1996', \
                          'Y1997': '1997', 'Y1998': '1998', 'Y1999': '1999', \
                          'Y2000': '2000', 'Y2001': '2001', 'Y2002': '2002', \
                          'Y2003': '2003', 'Y2004': '2004', 'Y2005': '2005', \
                          'Y2006': '2006', 'Y2007': '2007', 'Y2008': '2008', \
                          'Y2009': '2009', 'Y2010': '2010', 'Y2011': '2011', \
                          'Y2012': '2012', 'Y2013': '2013', 'Y2014': '2014', \
                          'Y2015': '2015', 'Y2016': '2016', 'Y2017': '2017', \
                          'Y2018': '2018', 'Y2019': '2019', 'Y2020': '2020', \
                          'Y2021': '2021', 'Y2022': '2022', 'Y1987': '1987'
                         
                        }, inplace = True)
med_data.head()
# Out:
#    Code                                        Item          Group  Region(#)  \
# 0     1  Personal Health Care (Millions of Dollars)  United States          0
# 1     1  Personal Health Care (Millions of Dollars)         Region          1
# 2     1  Personal Health Care (Millions of Dollars)          State          1
# 3     1  Personal Health Care (Millions of Dollars)          State          1
# 4     1  Personal Health Care (Millions of Dollars)          State          1
#
#           Region          State    1980    1981    1982    1983  ...     2012  \
# 0  United States            NaN  214321  248626  279493  308006  ...  2346962
# 1    New England            NaN   12830   14696   16591   18253  ...   138949
# 2    New England    Connecticut    3135    3612    4134    4587  ...    33053
# 3    New England          Maine     975    1113    1259    1388  ...    11254
# 4    New England  Massachusetts    6681    7622    8528    9306  ...    68298
#
#       2013     2014     2015     2016     2017     2018     2019     2020  \
# 0  2405667  2527325  2674089  2795322  2905160  3021796  3175230  3357832
# 1   142116   147335   155204   161570   166222   172908   180314   189004
# 2    33864    35243    36774    38059    38987    40587    42192    44372
# 3    11325    11759    12356    12940    13489    14273    15037    15912
# 4    69806    72256    76803    80436    82772    86111    89902    93737
#
#    Average_Annual_Percent_Growth
# 0                            7.1
# 1                            7.0
# 2                            6.8
# 3                            7.2
# 4                            6.8
#
# [5 rows x 48 columns]

# %%
med_data.rename(columns = {'Average_Annual_Percent_Growth': 'Avg An Growth(%)'}, inplace = True)
med_data
# Out:
#      Code                                               Item          Group  \
# 0       1         Personal Health Care (Millions of Dollars)  United States
# 1       1         Personal Health Care (Millions of Dollars)         Region
# 2       1         Personal Health Care (Millions of Dollars)          State
# 3       1         Personal Health Care (Millions of Dollars)          State
# 4       1         Personal Health Care (Millions of Dollars)          State
# ..    ...                                                ...            ...
# 655    11  Other Non-durable Medical Products (Millions o...          State
# 656    11  Other Non-durable Medical Products (Millions o...          State
# 657    11  Other Non-durable Medical Products (Millions o...          State
# 658    11  Other Non-durable Medical Products (Millions o...          State
# 659    11  Other Non-durable Medical Products (Millions o...          State
#
#      Region(#)         Region          State    1980    1981    1982    1983  \
# 0            0  United States            NaN  214321  248626  279493  308006
# 1            1    New England            NaN   12830   14696   16591   18253
# 2            1    New England    Connecticut    3135    3612    4134    4587
# 3            1    New England          Maine     975    1113    1259    1388
# 4            1    New England  Massachusetts    6681    7622    8528    9306
# ..         ...            ...            ...     ...     ...     ...     ...
# 655          8       Far West     California     923    1071    1201    1330
# 656          8       Far West         Hawaii      50      57      65      77
# 657          8       Far West         Nevada      39      44      48      52
# 658          8       Far West         Oregon     106     119     128     140
# 659          8       Far West     Washington     148     174     198     222
#
#      ...     2012     2013     2014     2015     2016     2017     2018  \
# 0    ...  2346962  2405667  2527325  2674089  2795322  2905160  3021796
# 1    ...   138949   142116   147335   155204   161570   166222   172908
# 2    ...    33053    33864    35243    36774    38059    38987    40587
# 3    ...    11254    11325    11759    12356    12940    13489    14273
# 4    ...    68298    69806    72256    76803    80436    82772    86111
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 655  ...     8161     8434     8809     9468     9902    10136    10588
# 656  ...      316      346      379      424      468      506      519
# 657  ...      801      757      735      742      717      696      725
# 658  ...      591      609      636      684      717      742      778
# 659  ...     1038     1105     1195     1303     1410     1507     1593
#
#         2019     2020  Avg An Growth(%)
# 0    3175230  3357832               7.1
# 1     180314   189004               7.0
# 2      42192    44372               6.8
# 3      15037    15912               7.2
# 4      89902    93737               6.8
# ..       ...      ...               ...
# 655    11203    11982               6.6
# 656      542      577               6.3
# 657      748      785               7.8
# 658      813      866               5.4
# 659     1676     1766               6.4
#
# [660 rows x 48 columns]

# %%
# Drop columns we don't need
list = ['Code', 'Region(#)', 'Region']
med_data = med_data.drop(list, axis = "columns")
med_data.head()
# Out:
#                                          Item          Group          State  \
# 0  Personal Health Care (Millions of Dollars)  United States            NaN
# 1  Personal Health Care (Millions of Dollars)         Region            NaN
# 2  Personal Health Care (Millions of Dollars)          State    Connecticut
# 3  Personal Health Care (Millions of Dollars)          State          Maine
# 4  Personal Health Care (Millions of Dollars)          State  Massachusetts
#
#      1980    1981    1982    1983    1984    1985    1986  ...     2012  \
# 0  214321  248626  279493  308006  337879  372633  405373  ...  2346962
# 1   12830   14696   16591   18253   20068   21840   24126  ...   138949
# 2    3135    3612    4134    4587    5083    5551    6171  ...    33053
# 3     975    1113    1259    1388    1512    1640    1779  ...    11254
# 4    6681    7622    8528    9306   10202   11005   12099  ...    68298
#
#       2013     2014     2015     2016     2017     2018     2019     2020  \
# 0  2405667  2527325  2674089  2795322  2905160  3021796  3175230  3357832
# 1   142116   147335   155204   161570   166222   172908   180314   189004
# 2    33864    35243    36774    38059    38987    40587    42192    44372
# 3    11325    11759    12356    12940    13489    14273    15037    15912
# 4    69806    72256    76803    80436    82772    86111    89902    93737
#
#    Avg An Growth(%)
# 0               7.1
# 1               7.0
# 2               6.8
# 3               7.2
# 4               6.8
#
# [5 rows x 45 columns]

# %%
# Filter 'Group' column to just show state
med_data.dropna(subset=['State'], inplace = True)
med_data
# Out:
#                                                   Item  Group          State  \
# 2           Personal Health Care (Millions of Dollars)  State    Connecticut
# 3           Personal Health Care (Millions of Dollars)  State          Maine
# 4           Personal Health Care (Millions of Dollars)  State  Massachusetts
# 5           Personal Health Care (Millions of Dollars)  State  New Hampshire
# 6           Personal Health Care (Millions of Dollars)  State   Rhode Island
# ..                                                 ...    ...            ...
# 655  Other Non-durable Medical Products (Millions o...  State     California
# 656  Other Non-durable Medical Products (Millions o...  State         Hawaii
# 657  Other Non-durable Medical Products (Millions o...  State         Nevada
# 658  Other Non-durable Medical Products (Millions o...  State         Oregon
# 659  Other Non-durable Medical Products (Millions o...  State     Washington
#
#      1980  1981  1982  1983   1984   1985   1986  ...   2012   2013   2014  \
# 2    3135  3612  4134  4587   5083   5551   6171  ...  33053  33864  35243
# 3     975  1113  1259  1388   1512   1640   1779  ...  11254  11325  11759
# 4    6681  7622  8528  9306  10202  11005  12099  ...  68298  69806  72256
# 5     672   795   912  1015   1138   1294   1481  ...  11497  11781  12086
# 6     982  1107  1238  1393   1535   1699   1867  ...   9425   9582  10047
# ..    ...   ...   ...   ...    ...    ...    ...  ...    ...    ...    ...
# 655   923  1071  1201  1330   1458   1572   1713  ...   8161   8434   8809
# 656    50    57    65    77     85     94    106  ...    316    346    379
# 657    39    44    48    52     56     60     65  ...    801    757    735
# 658   106   119   128   140    149    155    166  ...    591    609    636
# 659   148   174   198   222    241    262    291  ...   1038   1105   1195
#
#       2015   2016   2017   2018   2019   2020  Avg An Growth(%)
# 2    36774  38059  38987  40587  42192  44372               6.8
# 3    12356  12940  13489  14273  15037  15912               7.2
# 4    76803  80436  82772  86111  89902  93737               6.8
# 5    12585  13091  13656  14255  14826  15631               8.2
# 6    10510  10756  10917  11110  11619  12361               6.5
# ..     ...    ...    ...    ...    ...    ...               ...
# 655   9468   9902  10136  10588  11203  11982               6.6
# 656    424    468    506    519    542    577               6.3
# 657    742    717    696    725    748    785               7.8
# 658    684    717    742    778    813    866               5.4
# 659   1303   1410   1507   1593   1676   1766               6.4
#
# [561 rows x 45 columns]

# %%
# Export to csv
med_data.to_csv("Resources/med_data.csv", index=False)

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['project_3']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['med_data']

# %%
# assign the collection to a variable
med_data = db['med_data']

# %%
# Print one entry
pprint(db.med_data.find_one())
# Out:
# {'1980': 3135,
#  '1981': 3612,
#  '1982': 4134,
#  '1983': 4587,
#  '1984': 5083,
#  '1985': 5551,
#  '1986': 6171,
#  '1987': 6946,
#  '1988': 7964,
#  '1989': 9096,
#  '1990': 10032,
#  '1991': 10927,
#  '1992': 11673,
#  '1993': 12297,
#  '1994': 12888,
#  '1995': 13740,
#  '1996': 14206,
#  '1997': 15019,
#  '1998': 15934,
#  '1999': 16735,
#  '2000': 17625,
#  '2001': 18989,
#  '2002': 20446,
#  '2003': 21559,
#  '2004': 23380,
#  '2005': 24368,
#  '2006': 25838,
#  '2007': 27326,
#  '2008': 28876,
#  '2009': 30866,
#  '2010': 31444,
#  '2011': 31849,
#  '2012': 33053,
#  '2013': 33864,
#  '2014': 35243,
#  '2015': 36774,
#  '2016': 38059,
#  '2017': 38987,
#  '2018': 40587,
#  '2019': 42192,
#  '2020': 44372,
#  'Avg An Growth(%)': 6.8,
#  'Group': 'State',
#  'Item': 'Personal Health Care (Millions of Dollars)',
#  'State': 'Connecticut',
#  '_id': ObjectId('65b852edcea5de27399933fd')}

# %%
# Print all entries
query = {'Group': 'State'}
med_data_all = med_data.find(query)
med_data_all_df = pd.DataFrame(med_data_all)
med_data_all_df.head()
# Out:
#                         _id  1980  1981  1982  1983   1984   1985   1986  \
# 0  65b852edcea5de27399933fd  3135  3612  4134  4587   5083   5551   6171
# 1  65b852edcea5de27399933fe   975  1113  1259  1388   1512   1640   1779
# 2  65b852edcea5de27399933ff  6681  7622  8528  9306  10202  11005  12099
# 3  65b852edcea5de2739993400   672   795   912  1015   1138   1294   1481
# 4  65b852edcea5de2739993401   982  1107  1238  1393   1535   1699   1867
#
#     1987   1988  ...   2015   2016   2017   2018   2019   2020  \
# 0   6946   7964  ...  36774  38059  38987  40587  42192  44372
# 1   1969   2268  ...  12356  12940  13489  14273  15037  15912
# 2  13485  15378  ...  76803  80436  82772  86111  89902  93737
# 3   1733   1954  ...  12585  13091  13656  14255  14826  15631
# 4   2028   2231  ...  10510  10756  10917  11110  11619  12361
#
#                                          Item  Group          State  \
# 0  Personal Health Care (Millions of Dollars)  State    Connecticut
# 1  Personal Health Care (Millions of Dollars)  State          Maine
# 2  Personal Health Care (Millions of Dollars)  State  Massachusetts
# 3  Personal Health Care (Millions of Dollars)  State  New Hampshire
# 4  Personal Health Care (Millions of Dollars)  State   Rhode Island
#
#    Avg An Growth(%)
# 0               6.8
# 1               7.2
# 2               6.8
# 3               8.2
# 4               6.5
#
# [5 rows x 46 columns]

# %%
# Print column names
print("Column Names:")
print(med_data_all_df.columns)
# Out:
# Column Names:
# Index(['_id', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', 'Item', 'Group',
#        'State', 'Avg An Growth(%)'],
#       dtype='object')

# %%
#New order of columns
new_order = ['_id', 'State', 'Group', 'Item', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
       '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2018', '2019', '2020']

# Create a new DataFrame with columns in the desired order
med_data_all_df_reorder = med_data_all_df[new_order]
med_data_all_df_reorder.head()
# Out:
#                         _id          State  Group  \
# 0  65b852edcea5de27399933fd    Connecticut  State
# 1  65b852edcea5de27399933fe          Maine  State
# 2  65b852edcea5de27399933ff  Massachusetts  State
# 3  65b852edcea5de2739993400  New Hampshire  State
# 4  65b852edcea5de2739993401   Rhode Island  State
#
#                                          Item  1980  1981  1982  1983   1984  \
# 0  Personal Health Care (Millions of Dollars)  3135  3612  4134  4587   5083
# 1  Personal Health Care (Millions of Dollars)   975  1113  1259  1388   1512
# 2  Personal Health Care (Millions of Dollars)  6681  7622  8528  9306  10202
# 3  Personal Health Care (Millions of Dollars)   672   795   912  1015   1138
# 4  Personal Health Care (Millions of Dollars)   982  1107  1238  1393   1535
#
#     1985  ...   2011   2012   2013   2014   2015   2016   2017   2018   2019  \
# 0   5551  ...  31849  33053  33864  35243  36774  38059  38987  40587  42192
# 1   1640  ...  11040  11254  11325  11759  12356  12940  13489  14273  15037
# 2  11005  ...  66222  68298  69806  72256  76803  80436  82772  86111  89902
# 3   1294  ...  11163  11497  11781  12086  12585  13091  13656  14255  14826
# 4   1699  ...   9196   9425   9582  10047  10510  10756  10917  11110  11619
#
#     2020
# 0  44372
# 1  15912
# 2  93737
# 3  15631
# 4  12361
#
# [5 rows x 45 columns]

# %%
# Drop columns we don't need
list = ['_id', 'Group']
med_data_all_df_reorder = med_data_all_df_reorder.drop(list, axis = "columns")
med_data_all_df_reorder.head()
# Out:
#            State                                        Item  1980  1981  \
# 0    Connecticut  Personal Health Care (Millions of Dollars)  3135  3612
# 1          Maine  Personal Health Care (Millions of Dollars)   975  1113
# 2  Massachusetts  Personal Health Care (Millions of Dollars)  6681  7622
# 3  New Hampshire  Personal Health Care (Millions of Dollars)   672   795
# 4   Rhode Island  Personal Health Care (Millions of Dollars)   982  1107
#
#    1982  1983   1984   1985   1986   1987  ...   2011   2012   2013   2014  \
# 0  4134  4587   5083   5551   6171   6946  ...  31849  33053  33864  35243
# 1  1259  1388   1512   1640   1779   1969  ...  11040  11254  11325  11759
# 2  8528  9306  10202  11005  12099  13485  ...  66222  68298  69806  72256
# 3   912  1015   1138   1294   1481   1733  ...  11163  11497  11781  12086
# 4  1238  1393   1535   1699   1867   2028  ...   9196   9425   9582  10047
#
#     2015   2016   2017   2018   2019   2020
# 0  36774  38059  38987  40587  42192  44372
# 1  12356  12940  13489  14273  15037  15912
# 2  76803  80436  82772  86111  89902  93737
# 3  12585  13091  13656  14255  14826  15631
# 4  10510  10756  10917  11110  11619  12361
#
# [5 rows x 43 columns]

# %%
# Reshape the DataFrame into long format
med_data_long_df = pd.melt(med_data_all_df_reorder, id_vars=['State', 'Item'], var_name='Year', value_name='Spending')
med_data_long_df.head()
# Out:
#            State                                        Item  Year  Spending
# 0    Connecticut  Personal Health Care (Millions of Dollars)  1980      3135
# 1          Maine  Personal Health Care (Millions of Dollars)  1980       975
# 2  Massachusetts  Personal Health Care (Millions of Dollars)  1980      6681
# 3  New Hampshire  Personal Health Care (Millions of Dollars)  1980       672
# 4   Rhode Island  Personal Health Care (Millions of Dollars)  1980       982

# %%
print(med_data_long_df)
# Out:
#                State                                               Item  Year  \
# 0        Connecticut         Personal Health Care (Millions of Dollars)  1980
# 1              Maine         Personal Health Care (Millions of Dollars)  1980
# 2      Massachusetts         Personal Health Care (Millions of Dollars)  1980
# 3      New Hampshire         Personal Health Care (Millions of Dollars)  1980
# 4       Rhode Island         Personal Health Care (Millions of Dollars)  1980
# ...              ...                                                ...   ...
# 22996     California  Other Non-durable Medical Products (Millions o...  2020
# 22997         Hawaii  Other Non-durable Medical Products (Millions o...  2020
# 22998         Nevada  Other Non-durable Medical Products (Millions o...  2020
# 22999         Oregon  Other Non-durable Medical Products (Millions o...  2020
# 23000     Washington  Other Non-durable Medical Products (Millions o...  2020
#
#        Spending
# 0          3135
# 1           975
# 2          6681
# 3           672
# 4           982
# ...         ...
# 22996     11982
# 22997       577
# 22998       785
# 22999       866
# 23000      1766
#
# [23001 rows x 4 columns]

# %%
unique_items = med_data_long_df["Item"].unique()

for item in unique_items:
    print(item)
# Out:
# Personal Health Care (Millions of Dollars)
# Hospital Care (Millions of Dollars)
# Physician & Clinical Services (Millions of Dollars)
# Other Professional Services (Millions of Dollars)
# Dental Services (Millions of Dollars)
# Other Health, Residential, and Personal Care (Millions of Dollars)
# Home Health Care (Millions of Dollars)
# Nursing Home Care (Millions of Dollars)
# Prescription Drugs (Millions of Dollars)
# Durable Medical Products (Millions of Dollars)
# Other Non-durable Medical Products (Millions of Dollars)

# %%
import matplotlib.pyplot as plt

# Filter for California
california_data = med_data_long_df[med_data_long_df['State'] == 'California']

california_data['Year'] = california_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = california_data['Item'].unique()

# loop through categories
for category in categories:
    category_data = california_data[california_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# chart title and labels
plt.title('Healthcare Spending by Category Over Time in California', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/391255292.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   california_data['Year'] = california_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Florida
florida_data = med_data_long_df[med_data_long_df['State'] == 'Florida']

florida_data['Year'] = florida_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = florida_data['Item'].unique()

# loop through categories
for category in categories:
    category_data = florida_data[florida_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Florida', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/859737981.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   florida_data['Year'] = florida_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Texas
texas_data = med_data_long_df[med_data_long_df['State'] == 'Texas']

texas_data['Year'] = texas_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = texas_data['Item'].unique()

#Loop through Categories
for category in categories:
    category_data = texas_data[texas_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Texas', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/2329032211.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   texas_data['Year'] = texas_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for New York
new_york_data = med_data_long_df[med_data_long_df['State'] == 'New York']

new_york_data['Year'] = new_york_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = new_york_data['Item'].unique()

# Loop through categories
for category in categories:
    category_data = new_york_data[new_york_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in New York', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/704379799.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_york_data['Year'] = new_york_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Pennsylvania
pennsylvania_data = med_data_long_df[med_data_long_df['State'] == 'Pennsylvania']

pennsylvania_data['Year'] = pennsylvania_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = pennsylvania_data['Item'].unique()

# Loop through categories
for category in categories:
    category_data = pennsylvania_data[pennsylvania_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Pennsylvania', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/116159698.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pennsylvania_data['Year'] = pennsylvania_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for South Dakota
south_dakota_data = med_data_long_df[med_data_long_df['State'] == 'South Dakota']

south_dakota_data['Year'] = south_dakota_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# unique categories (Items)
categories = south_dakota_data['Item'].unique()

# Loop through Categories
for category in categories:
    category_data = south_dakota_data[south_dakota_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in South Dakota', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/3923889932.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dakota_data['Year'] = south_dakota_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for North Dakota
north_dakota_data = med_data_long_df[med_data_long_df['State'] == 'North Dakota']

north_dakota_data['Year'] = north_dakota_data['Year'].astype(int)

# plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = north_dakota_data['Item'].unique()

# loop through categories
for category in categories:
    category_data = north_dakota_data[north_dakota_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in North Dakota', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/898709120.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dakota_data['Year'] = north_dakota_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Alaska
alaska_data = med_data_long_df[med_data_long_df['State'] == 'Alaska']

alaska_data['Year'] = alaska_data['Year'].astype(int)

# plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = alaska_data['Item'].unique()

# loop through each category
for category in categories:
    category_data = alaska_data[alaska_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Alaska', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/2379351563.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alaska_data['Year'] = alaska_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Vermont
vermont_data = med_data_long_df[med_data_long_df['State'] == 'Vermont']

vermont_data['Year'] = vermont_data['Year'].astype(int)

# plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = vermont_data['Item'].unique()

# loop through categories
for category in categories:
    category_data = vermont_data[vermont_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Vermont', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/132937666.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vermont_data['Year'] = vermont_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter for Wyoming
wyoming_data = med_data_long_df[med_data_long_df['State'] == 'Wyoming']

wyoming_data['Year'] = wyoming_data['Year'].astype(int)

# Plot figure size
plt.figure(figsize=(12, 6))

# Unique Categories
categories = wyoming_data['Item'].unique()

# loop through each category
for category in categories:
    category_data = wyoming_data[wyoming_data['Item'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# title and labels
plt.title('Healthcare Spending by Category Over Time in Wyoming', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/2507605320.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wyoming_data['Year'] = wyoming_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for California
personal_health_data = med_data_long_df[med_data_long_df['Item'] == 'Personal Health Care (Millions of Dollars)']

# Ensure 'Year' is of type int for proper plotting
personal_health_data['Year'] = personal_health_data['Year'].astype(int)

# Setting the figure size
plt.figure(figsize=(12, 6))

# Getting unique categories (Items)
categories = personal_health_data['State'].unique()

# Plotting each category with a loop
for category in categories:
    category_data = personal_health_data[personal_health_data['State'] == category]
    category_data = category_data.sort_values('Year')
    plt.plot(category_data['Year'], category_data['Spending'], label=category, marker='o')

# Adding title and labels
plt.title('Personal Healthcare Spending by State Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

# Adding a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/3749169345.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_health_data['Year'] = personal_health_data['Year'].astype(int)

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for the item "Personal Healthcare"
personal_healthcare_data = med_data_long_df[med_data_long_df['Item'] == 'Personal Health Care (Millions of Dollars)']

# Convert 'Year' and 'Spending' to appropriate types for proper plotting
personal_healthcare_data['Year'] = personal_healthcare_data['Year'].astype(int)
personal_healthcare_data['Spending'] = pd.to_numeric(personal_healthcare_data['Spending'], errors='coerce')

# Summing up the spending for each state and selecting the top 10 states
total_spending_by_state = personal_healthcare_data.groupby('State')['Spending'].sum().nlargest(10)
top_states = total_spending_by_state.index.tolist()

# Setting the figure size
plt.figure(figsize=(15, 8))

# Plotting each of the top states with a loop
for state in top_states:
    state_data = personal_healthcare_data[personal_healthcare_data['State'] == state]
    state_data = state_data.sort_values('Year')
    plt.plot(state_data['Year'], state_data['Spending'], label=state)

# Adding title and labels
plt.title('Top 10 States in Personal Healthcare Spending Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

# Adding a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/2506360899.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_healthcare_data['Year'] = personal_healthcare_data['Year'].astype(int)
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/2506360899.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_healthcare_data['Spending'] = pd.to_numeric(personal_healthcare_data['Spending'], errors='coerce')

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for the item "Personal Healthcare"
personal_healthcare_data = med_data_long_df[med_data_long_df['Item'] == 'Personal Health Care (Millions of Dollars)']

# Convert 'Year' and 'Spending' to appropriate types for proper plotting
personal_healthcare_data['Year'] = personal_healthcare_data['Year'].astype(int)
personal_healthcare_data['Spending'] = pd.to_numeric(personal_healthcare_data['Spending'], errors='coerce')

# sum up the spending for each state and selecting the top 10 states
total_spending_by_state = personal_healthcare_data.groupby('State')['Spending'].sum().nlargest(10)
top_states = total_spending_by_state.index.tolist()

# plot figure size
plt.figure(figsize=(15, 8))

# loop through states
for state in top_states:
    state_data = personal_healthcare_data[personal_healthcare_data['State'] == state]
    state_data = state_data.sort_values('Year')
    plt.plot(state_data['Year'], state_data['Spending'], label=state, linewidth=2, marker='o')  # Adjusted line width and added markers

# title and labels
plt.title('Top 10 States in Personal Healthcare Spending Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Spending (in Millions)', fontsize=14)

plt.legend()

plt.show()
# Out:
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/1904073911.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_healthcare_data['Year'] = personal_healthcare_data['Year'].astype(int)
# /var/folders/0l/4w__g0hs2xl76ggy5br32kwm0000gn/T/ipykernel_82684/1904073911.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_healthcare_data['Spending'] = pd.to_numeric(personal_healthcare_data['Spending'], errors='coerce')
